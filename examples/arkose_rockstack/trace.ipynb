# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:28:16.524183+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "Instruction text asking the user to use arrows to pick the group of rocks matching the amount indicated on the left.")
    describe(1, "A group of rocks displayed with left and right arrow buttons for navigation.")
    describe(2, "A black box displaying the number '5' as the target amount.")
    describe(3, "A 'Submit' button for finalizing the selection.")

    # Step 2: Identify the relationships between frames.
    relate(0, 2, "Frame 0 provides instructions to match the number in Frame 2.")
    relate(1, 2, "Frame 1 allows navigation to find a group of rocks matching the number in Frame 2.")
    relate(1, 3, "Frame 1's selection is finalized by clicking the 'Submit' button in Frame 3.")

    # Step 3: Identify the sequential events and final visual criteria.
    objective("""
    1. Read the instructions in Frame 0 to understand the task.
    2. Observe the target number displayed in Frame 2.
    3. Use the left and right arrows in Frame 1 to navigate through groups of rocks.
    4. Identify the group of rocks that matches the target number in Frame 2.
    5. Click the 'Submit' button in Frame 3 to finalize the selection.
    """)

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0 provides instructions, so it's not interactable
    # Frame 1 has arrows to select the group of rocks
    frame1 = frames[1]
    left_arrow = frame1.get_element('left', 'black circle with left arrow')
    right_arrow = frame1.get_element('right', 'black circle with right arrow')
    left_arrow.set_element_as('CLICKABLE')
    right_arrow.set_element_as('CLICKABLE')
    
    # Frame 2 displays the number, it's not interactable
    # Frame 3 has the 'Submit' button
    frame3 = frames[3]
    submit_button = frame3.get_element('center', 'Submit button')
    submit_button.set_element_as('NEXT')

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Get the target number of rocks from Frame 2
    target_number = ask([frames[2].image], "What is the number shown?", answer_type="int")[0]

    # Get all choices of rock groups from Frame 1
    left_arrow = frames[1].get_interactable(0)
    right_arrow = frames[1].get_interactable(1)
    choices = get_all_choices(left_arrow, right_arrow, frames[1])

    # Initialize variables to track the best choice
    best_choice = None
    best_difference = float('inf')

    # Iterate through each choice to find the closest match
    for choice in choices:
        # Mark rocks in the current choice image
        marked_image = mark([choice.image], "rock")
        # Count the number of rocks
        rock_count = ask(marked_image, "What is the number of rocks in the marked red boxes?", answer_type="int")[0]

        # Calculate the difference from the target
        difference = abs(target_number - rock_count)

        # Update the best choice if this one is closer
        if difference < best_difference:
            best_difference = difference
            best_choice = choice

    # Select the best choice
    if best_choice:
        best_choice.select()

    # Click the submit button in Frame 3
    submit_button = frames[3].get_interactable(0)
    click(submit_button)

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the number shown?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[5])
'''
TIME = 1.2404612768441439
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 506
PROMPT_TOKENS = 500
COMPLETION_TOKENS = 6

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the number of rocks in the marked red boxes?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.
## Guidelines
1. Focus on red boxes that are related, based on their shape, texture, and context, avoiding double-counting overlapping boxes.
2. Red boxes are not perfect, it may wrongly mark or miss objects (e.g., rocks and grass).
3. You should use the red boxes as a reference rather than ground truth.
'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[3])
'''
TIME = 1.807354527991265
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 394
PROMPT_TOKENS = 389
COMPLETION_TOKENS = 5

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the number of rocks in the marked red boxes?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.
## Guidelines
1. Focus on red boxes that are related, based on their shape, texture, and context, avoiding double-counting overlapping boxes.
2. Red boxes are not perfect, it may wrongly mark or miss objects (e.g., rocks and grass).
3. You should use the red boxes as a reference rather than ground truth.
'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[2])
'''
TIME = 1.2619701130315661
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 580
PROMPT_TOKENS = 574
COMPLETION_TOKENS = 6

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the number of rocks in the marked red boxes?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.
## Guidelines
1. Focus on red boxes that are related, based on their shape, texture, and context, avoiding double-counting overlapping boxes.
2. Red boxes are not perfect, it may wrongly mark or miss objects (e.g., rocks and grass).
3. You should use the red boxes as a reference rather than ground truth.
'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[3])
'''
TIME = 1.1689255177043378
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 580
PROMPT_TOKENS = 574
COMPLETION_TOKENS = 6

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the number of rocks in the marked red boxes?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.
## Guidelines
1. Focus on red boxes that are related, based on their shape, texture, and context, avoiding double-counting overlapping boxes.
2. Red boxes are not perfect, it may wrongly mark or miss objects (e.g., rocks and grass).
3. You should use the red boxes as a reference rather than ground truth.
'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[1])
'''
TIME = 1.273274906910956
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 580
PROMPT_TOKENS = 574
COMPLETION_TOKENS = 6

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the number of rocks in the marked red boxes?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.
## Guidelines
1. Focus on red boxes that are related, based on their shape, texture, and context, avoiding double-counting overlapping boxes.
2. Red boxes are not perfect, it may wrongly mark or miss objects (e.g., rocks and grass).
3. You should use the red boxes as a reference rather than ground truth.
'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[5])
'''
TIME = 1.2973071532323956
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 580
PROMPT_TOKENS = 574
COMPLETION_TOKENS = 6

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the number of rocks in the marked red boxes?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.
## Guidelines
1. Focus on red boxes that are related, based on their shape, texture, and context, avoiding double-counting overlapping boxes.
2. Red boxes are not perfect, it may wrongly mark or miss objects (e.g., rocks and grass).
3. You should use the red boxes as a reference rather than ground truth.
'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[1])
'''
TIME = 1.1540364418178797
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 580
PROMPT_TOKENS = 574
COMPLETION_TOKENS = 6

# %% [markdown]
# ---
