# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:15:57.121279+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "A prompt instructs the user to pick one square that shows two identical objects (1 of 1).")
    describe(1, "A grid of six squares, each containing two objects, with varying designs and backgrounds.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 1 provides the options to fulfill the task described in Frame 0.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective("Click on the square in Frame 1 that contains two identical objects to solve the task described in Frame 0.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0 is the instruction frame, so it is non-interactable
    # Frame 1 contains the squares with objects, which are interactable

    # Split Frame 1 into 6 selectable subframes (2 rows, 3 columns)
    subframes = frames[1].split(rows=2, columns=3)

    # Set each subframe as SELECTABLE
    for subframe in subframes:
        subframe.set_frame_as(interactable="SELECTABLE")

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Mark objects in each frame
    marked_images = mark([frame.image for frame in frames[1:]], "object")
    
    # Ask which frame contains two identical objects
    identical_objects = ask(marked_images, "Does this image contain two identical objects?", answer_type="bool")
    
    # Select the frame with two identical objects
    for i, identical in enumerate(identical_objects):
        if identical:
            select(frames[i + 1])
            break

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: Does this image contain two identical objects?
Output a list of (True/False) for each image.
You should follow the format `answer(booleans=[True, False, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(booleans=[True, False, False, False, False, False])
'''
TIME = 2.6591100567020476
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1592
PROMPT_TOKENS = 1573
COMPLETION_TOKENS = 19

# %% [markdown]
# ---
