# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:13:30.361446+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "A text prompt instructs the user to click on the entity that is made by humans, with a 'Skip' button at the bottom right.")
    describe(1, "A colorful grid contains various entities, including tigers, a cabbage, and a motorcycle.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides the instruction, and Frame 1 contains the entities to choose from.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective("Click on the entity in Frame 1 that matches the criteria described in the instruction from Frame 0, which is 'made by humans'.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    for frame in frames:
        if frame == frames[0]:  # Frame 0
            # Get the 'Skip' button and mark it as NEXT
            skip_button = frame.get_element(position="down", details="green verify button")
            skip_button.set_element_as(interactable="NEXT")
        
        elif frame == frames[1]:  # Frame 1
            # Mark the frame as POINTABLE for selecting matching entities
            frame.set_frame_as(interactable="POINTABLE")

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    instruction = ask([frames[0].image], "What is the instruction? If there are images, include their context in the instruction", "str")[-1]

    marked_image = frames[1].show_keypoints("all")

    keypoint_id = ask([marked_image], f"Which number matches the objective: {instruction}", "int")[-1]

    keypoint = frames[1].get_keypoint(keypoint_id)

    point(to=keypoint)

    skip_button_frame_0 = frames[0].get_interactable(0)
    click(skip_button_frame_0)

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the instruction? If there are images, include their context in the instruction
Output a list of strings for each image.
You should follow the format `answer(strings=["a", "b", ...])` to answer the question.

'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(strings=["Please click on the entity that is made by humans."])
'''
TIME = 2.1462993565946817
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 944
PROMPT_TOKENS = 928
COMPLETION_TOKENS = 16

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: Which number matches the objective: Please click on the entity that is made by humans.
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[27])
'''
TIME = 1.40394542273134
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 656
PROMPT_TOKENS = 650
COMPLETION_TOKENS = 6

# %% [markdown]
# ---
