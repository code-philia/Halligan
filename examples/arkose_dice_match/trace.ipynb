# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:27:04.076708+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "Instruction text reads 'Click the arrows to sum the dice and match the number on the left (1 of 1)'.")
    describe(1, "A set of red dice with numbers visible, flanked by left and right arrow buttons.")
    describe(2, "A bold number '12' displayed on a background.")
    describe(3, "A 'Submit' button on a dark background.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides instructions for interacting with the dice in Frame 1.")
    relate(1, 2, "Frame 1 allows manipulation of dice to match the target number shown in Frame 2.")
    relate(1, 3, "Frame 1's interaction leads to the final action of clicking the 'Submit' button in Frame 3.")

    # Step 3: Identify the sequential events and final visual criteria.
    objective("Click the left or right arrows to adjust the dice values in Frame 1, ensuring their sum matches the target number displayed in Frame 2, and then click the 'Submit' button in Frame 3 to complete the task.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0: Instructions
    frame_0 = frames[0]
    frame_0.set_frame_as(interactable="POINTABLE")

    # Frame 1: Dice with arrows
    frame_1 = frames[1]
    left_arrow = frame_1.get_element(position="left", details="black circle with left arrow")
    right_arrow = frame_1.get_element(position="right", details="black circle with right arrow")
    left_arrow.set_element_as(interactable="CLICKABLE")
    right_arrow.set_element_as(interactable="CLICKABLE")

    # Frame 2: Target number
    # This frame is dependent and non-interactable

    # Frame 3: Submit button
    frame_3 = frames[3]
    submit_button = frame_3.get_element(position="center", details="Submit button")
    submit_button.set_element_as(interactable="NEXT")

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Extract the target number from Frame 2
    target_image = frames[2].image
    target_number = ask([target_image], "What is the target number?", answer_type="int")[0]

    # Get all possible dice configurations by cycling through choices
    left_arrow = frames[1].get_interactable(0)
    right_arrow = frames[1].get_interactable(1)
    choices = get_all_choices(left_arrow, right_arrow, frames[1])

    # Initialize variables to track the best choice
    best_choice = None
    best_difference = float('inf')

    # Iterate through each choice to find the closest sum to the target number
    for choice in choices:
        # Focus on the dice in the current choice
        dice_patches = focus(choice.image, "dice")
        dice_numbers = ask(dice_patches, "What is the die number?", answer_type="int")
        dice_sum = sum(dice_numbers)

        # Calculate the difference from the target
        difference = abs(target_number - dice_sum)

        # Update the best choice if this one is closer
        if difference < best_difference:
            best_difference = difference
            best_choice = choice

    # Select the best choice
    if best_choice:
        best_choice.select()

    # Click the submit button in Frame 3
    submit_button = frames[3].get_interactable(0)
    click(submit_button)

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the target number?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[12])
'''
TIME = 1.2404725477099419
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 506
PROMPT_TOKENS = 500
COMPLETION_TOKENS = 6

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the die number?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 5
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[5, 3, 4, 5, 6])
'''
TIME = 4.228273066692054
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1370
PROMPT_TOKENS = 1352
COMPLETION_TOKENS = 18

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the die number?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[2, 3, 2, 1, 4])
'''
TIME = 2.618048224132508
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1583
PROMPT_TOKENS = 1565
COMPLETION_TOKENS = 18

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the die number?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[2, 4, 5, 5, 2])
'''
TIME = 2.0559533103369176
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1583
PROMPT_TOKENS = 1565
COMPLETION_TOKENS = 18

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the die number?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[1, 3, 1, 4, 6])
'''
TIME = 2.7610654891468585
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1583
PROMPT_TOKENS = 1565
COMPLETION_TOKENS = 18

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the die number?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[4, 6, 1, 4, 5])
'''
TIME = 2.2702826778404415
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1583
PROMPT_TOKENS = 1565
COMPLETION_TOKENS = 18

# %% [markdown]
# ---
