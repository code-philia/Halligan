# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:38:22.583883+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "The frame contains an instruction: 'Please click on the lowercase letter corresponding to the yellow letter.'")
    describe(1, "The frame contains a 3D scene with various colorful objects, including letters, numbers, and shapes, with a yellow uppercase 'D' and a yellow lowercase 'd' visible.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides the instruction to interact with the objects in Frame 1.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective("Click on the lowercase letter that matches the yellow uppercase letter in the scene, following the instruction provided.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0 provides instructions, so it is non-interactable
    # Frame 1 contains the objects to interact with

    # Get Frame 1
    frame1 = frames[1]

    # Mark Frame 1 as POINTABLE since it contains multiple objects
    frame1.set_frame_as(interactable="POINTABLE")

    # Return the modified frames
    return frames

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames: list) -> None:
    # Step 1: Annotate keypoints in Frame 1
    keypoint_image = frames[1].show_keypoints(region="all")

    # Step 2: Ask a question to identify the lowercase letter corresponding to the yellow uppercase letter
    initial_answer = ask([keypoint_image], "point to the lowercase letter corresponding to the yellow uppercase letter", answer_type="int")

    # Step 3: Get the keypoint corresponding to the initial answer
    initial_keypoint = frames[1].get_keypoint(id=initial_answer[0])

    # Step 4: Show neighbours of the initial keypoint to narrow down the search space
    neighbour_image = initial_keypoint.show_neighbours()

    # Step 5: Refine the answer by asking again within the narrowed-down search space
    refined_answer = ask([neighbour_image], "point to the lowercase letter corresponding to the yellow uppercase letter", answer_type="int")

    # Step 6: Get the refined keypoint corresponding to the refined answer
    refined_keypoint = initial_keypoint.get_neighbour(id=refined_answer[0])

    # Step 7: Click on the identified keypoint
    point(to=refined_keypoint)

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: point to the lowercase letter corresponding to the yellow uppercase letter
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[28])
'''
TIME = 4.815238361246884
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 512
PROMPT_TOKENS = 506
COMPLETION_TOKENS = 6

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: point to the lowercase letter corresponding to the yellow uppercase letter
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 1
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[8])
'''
TIME = 1.2277582590468228
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 512
PROMPT_TOKENS = 506
COMPLETION_TOKENS = 6

# %% [markdown]
# ---
