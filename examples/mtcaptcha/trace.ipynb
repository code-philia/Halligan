# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:34:40.381601+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(frame_id=0, description="A rectangular input field with a placeholder text 'Enter text from image'.")
    describe(frame_id=1, description="A distorted image containing alphanumeric characters '2xr29D2' in a colorful background.")

    # Step 2: Identify the relationships between frames.
    relate(frame_id1=1, frame_id2=0, relationship="Frame 1 provides the alphanumeric text to be entered into the input field in Frame 0.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective(description="To solve the task, first identify the alphanumeric text in Frame 1, then click on the input field in Frame 0, and finally type the identified text into the input field to complete the task.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0: Input field
    frame_0 = frames[0]
    input_element = frame_0.get_element(position='down', details='rectangular input field')
    input_element.set_element_as('INPUTTABLE')

    # Frame 1: Distorted text
    frame_1 = frames[1]
    # Frame 1 is dependent on Frame 0, so it is non-interactable

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames: list) -> None:
    # Extract the CAPTCHA text from the image in Frame 1
    captcha_image = frames[1].image
    captcha_text = "2xr29D2"  # Manually identified from the image

    # Get the input field element in Frame 0
    input_field = frames[0].get_interactable(0)

    # Enter the CAPTCHA text into the input field
    enter(input_field, captcha_text)

# %% [markdown]
# ---
