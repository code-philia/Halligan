# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:16:54.353964+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "A prompt instructs the user to 'Pick the spiral galaxy (1 of 1)' with no visible options in this frame.")
    describe(1, "A grid of six images showing various galaxy-like patterns, one of which is a distinct spiral galaxy.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 1 provides the visual options to fulfill the instruction in Frame 0.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective("Click on the image in Frame 1 that matches the description of a spiral galaxy as instructed in Frame 0.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0 is a prompt and not interactable
    # Frame 1 contains the grid of images
    frame1 = frames[1]
    
    # Split Frame 1 into a grid of 6 images
    subframes = frame1.split(rows=2, columns=3)
    
    # Mark each subframe as SELECTABLE since we need to click one of them
    for subframe in subframes:
        subframe.set_frame_as(interactable="SELECTABLE")

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Extract images from frames 1 to 6
    images = [frame.image for frame in frames[1:7]]
    
    # Ask which image contains a spiral galaxy pattern
    spiral_galaxy_indices = ask(images, "Which image contains a spiral galaxy pattern?", answer_type="int")
    
    # Select the frame with the spiral galaxy
    select(frames[spiral_galaxy_indices[0] + 1])

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: Which image contains a spiral galaxy pattern?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[3])
'''
TIME = 3.4061908600851893
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1573
PROMPT_TOKENS = 1567
COMPLETION_TOKENS = 6

# %% [markdown]
# ---
