# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:39:40.245050+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "A text prompt instructing the user to 'Enter the code from the image'.")
    describe(1, "An image containing distorted text that reads 'alleyway lather'.")
    describe(2, "A blue rectangular button labeled 'Submit'.")
    describe(3, "A rectangular input field with a placeholder text 'Uppercase or lowercase letters'.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides instructions to extract the code from Frame 1.")
    relate(1, 3, "Frame 1 provides the code to be entered into the input field in Frame 3.")
    relate(3, 2, "Frame 3 requires input before clicking the 'Submit' button in Frame 2.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective(
        "To solve the task, the user must visually identify the distorted text in the image (Frame 1), "
        "click on the input field (Frame 3), type the identified text (case-insensitive), "
        "and then click the 'Submit' button (Frame 2) to complete the process."
    )

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 1: Distorted text image
    frame1 = frames[1]
    element1 = frame1.get_element(position='center', details='distorted text')
    element1.set_element_as(interactable='DRAGGABLE')

    # Frame 3: Input field
    frame3 = frames[3]
    element3 = frame3.get_element(position='center', details='input field')
    element3.set_element_as(interactable='INPUTTABLE')

    # Frame 2: Submit button
    frame2 = frames[2]
    element2 = frame2.get_element(position='center', details='blue button')
    element2.set_element_as(interactable='NEXT')

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames: list) -> None:
    # Extract the CAPTCHA text from the image in Frame 1
    captcha_image = frames[1].image
    captcha_text = "alleyway lather"  # Manually identified from the image

    # Get the input field element in Frame 3
    input_field = frames[3].get_interactable(0)

    # Enter the CAPTCHA text into the input field
    enter(input_field, captcha_text)

    # Click the "Submit" button in Frame 2
    submit_button = frames[2].get_interactable(0)
    click(submit_button)

# %% [markdown]
# ---
