# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:43:51.713955+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "Text instruction reads 'Move the slider to complete the puzzle'.")
    describe(1, "A grid of shuffled image tiles resembling a stadium or field, forming a puzzle.")
    describe(2, "A blue slider button with an arrow pointing right and text 'Pull to the right'.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides instructions for solving the puzzle in Frame 1.")
    relate(2, 1, "Frame 2 provides the slider mechanism to rearrange the tiles in Frame 1.")

    # Step 3: Identify the sequential events and final visual criteria.
    objective("Click and drag the slider in Frame 2 to rearrange the tiles in Frame 1, aligning them to form a coherent image as per the instruction in Frame 0.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 2 contains the slider, which is the main interactable element
    slider = frames[2].get_element(position='left', details='blue button with an arrow pointing right')
    slider.set_element_as(interactable='SLIDEABLE_X')

    # Frame 1 is dependent on Frame 2, so it should not be marked as interactable
    # Frame 0 is also dependent on Frame 2, so it should not be marked as interactable

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Get the slider handle from Frame 2
    slider_handle = frames[2].get_interactable(0)

    # Slide the handle to the right while observing changes in Frame 1
    observations = slide_x(slider_handle, direction="right", observe_frame=frames[1])

    # Extract images from observations
    images = [choice.image for choice in observations]

    # Rank the images based on the task objective: completing the puzzle
    ranked_ids = rank(images, task_objective="Complete the image puzzle")

    # Select the best choice based on the highest rank
    best_choice = observations[ranked_ids[0]]

    # Refine the search around the best choice
    refined_choices = best_choice.refine()

    # Further rank the refined choices
    refined_images = [choice.image for choice in refined_choices]
    refined_ranked_ids = rank(refined_images, task_objective="Complete the image puzzle")

    # Select the best refined choice
    final_choice = refined_choices[refined_ranked_ids[0]]

    # Release the slider at the best position
    final_choice.release()

# %%
PROMPT = '''
Given a list of images, rank them based on their relevance to the objective: Complete the image puzzle.
You should follow the format rank(ids=[1, 2, ...]) to output a ranked list of image ids.
## Guidelines
1. Some of the tiles are scrambled.
2. Determine which image is complete based on tile color, texture, and alignment.
'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
To rank the images based on their relevance to completing the puzzle, we need to evaluate the alignment, color, and texture of the tiles. A complete image will have all tiles correctly aligned without any mismatches.

### Analysis:
1. **Image 0**: Appears to be complete with all tiles aligned correctly.
2. **Image 1**: Some tiles are scrambled, disrupting the alignment.
3. **Image 2**: Several tiles are scrambled, disrupting the alignment.
4. **Image 3**: Multiple tiles are scrambled, disrupting the alignment.
5. **Image 4**: Some tiles are scrambled, disrupting the alignment.
6. **Image 5**: Some tiles are scrambled, disrupting the alignment.

### Ranking:
- **Image 0** is the most complete.
- The rest of the images have varying degrees of scrambling, but they are less complete than Image 0.

### Final Output:
```plaintext
rank(ids=[0, 1, 4, 5, 2, 3])
```
'''
TIME = 5.688617778010666
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1802
PROMPT_TOKENS = 1588
COMPLETION_TOKENS = 214

# %% [markdown]
# ---

# %%
PROMPT = '''
Given a list of images, rank them based on their relevance to the objective: Complete the image puzzle.
You should follow the format rank(ids=[1, 2, ...]) to output a ranked list of image ids.
## Guidelines
1. Some of the tiles are scrambled.
2. Determine which image is complete based on tile color, texture, and alignment.
'''

# %%
IMAGES = 10
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div><div><img src="data:image/png;base64,..."/><p>Image 6</p></div><div><img src="data:image/png;base64,..."/><p>Image 7</p></div><div><img src="data:image/png;base64,..."/><p>Image 8</p></div><div><img src="data:image/png;base64,..."/><p>Image 9</p></div>
#     </div>

# %%
RESPONSE = '''
rank(ids=[7, 8, 9, 5, 6, 2, 3, 4, 0, 1])
'''
TIME = 3.388023001141846
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 2473
PROMPT_TOKENS = 2440
COMPLETION_TOKENS = 33

# %% [markdown]
# ---
