# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:29:20.277046+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "Instruction text prompting the user to use arrows to change the number of objects to match the left image.")
    describe(1, "A black-and-white image with two abstract shapes and left/right arrow buttons below it.")
    describe(2, "A black background with '4 x' followed by a game controller icon.")
    describe(3, "A dark rectangular button labeled 'Submit'.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides instructions for interacting with the arrows in Frame 1.")
    relate(1, 2, "Frame 1's arrows adjust the count of objects, which is represented numerically in Frame 2.")
    relate(2, 3, "Frame 2's count is finalized and submitted using the button in Frame 3.")

    # Step 3: Identify the sequential events and final visual criteria.
    objective("Click the left or right arrows in Frame 1 to adjust the number of objects until the count matches the target in Frame 2, then click the 'Submit' button in Frame 3.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0: Instructions, related to Frame 1
    # Frame 1: Contains arrows for navigation
    left_arrow = frames[1].get_element(position='left', details='circular arrow')
    right_arrow = frames[1].get_element(position='right', details='circular arrow')
    left_arrow.set_element_as(interactable='CLICKABLE')
    right_arrow.set_element_as(interactable='CLICKABLE')
    
    # Frame 2: Symbols, related to Frame 3
    # No interactables needed here as per the task description
    
    # Frame 3: Submit button
    submit_button = frames[3].get_element(position='center', details='Submit button')
    submit_button.set_element_as(interactable='NEXT')

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Get the arrows for navigation in Frame 1
    left_arrow = frames[1].get_interactable(0)
    right_arrow = frames[1].get_interactable(1)

    # Get all choices by cycling through Frame 1
    choices = get_all_choices(left_arrow, right_arrow, frames[1])

    # Reference image from Frame 2
    reference_image = frames[2].image

    # Iterate through each choice to find the correct one
    for choice in choices:
        # Mark the objects in the current choice
        marked_image = mark([choice.image], "object")

        # Compare the marked image with the reference image
        comparison = compare(marked_image, "Does this match the reference symbols?", reference_image)

        # If the comparison is True, select this choice
        if comparison[0]:
            choice.select()
            break

    # Click the submit button in Frame 3
    submit_button = frames[3].get_interactable(0)
    click(submit_button)

# %%
PROMPT = '''
## Objective
Given the list of items, compare them with Reference and see if it satisfies the objective: Does this match the reference symbols?
Output a list of (True/False) for each item.
You should follow the format answer(booleans=[True, False, ...]) to answer the question.
## Guidelines
1. The expression 'N x' indicates that there should be N of the reference icons.
2. Find the image with N number of matching icons as in reference.
'''

# %%
IMAGES = 2
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Reference</p></div><div><img src="data:image/png;base64,..."/><p>Item 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(booleans=[False])
'''
TIME = 1.422795170918107
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 769
PROMPT_TOKENS = 760
COMPLETION_TOKENS = 9

# %% [markdown]
# ---

# %%
PROMPT = '''
## Objective
Given the list of items, compare them with Reference and see if it satisfies the objective: Does this match the reference symbols?
Output a list of (True/False) for each item.
You should follow the format answer(booleans=[True, False, ...]) to answer the question.
## Guidelines
1. The expression 'N x' indicates that there should be N of the reference icons.
2. Find the image with N number of matching icons as in reference.
'''

# %%
IMAGES = 2
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Reference</p></div><div><img src="data:image/png;base64,..."/><p>Item 0</p></div>
#     </div>

# %%
RESPONSE = '''
answer(booleans=[True])
'''
TIME = 1.2777210189960897
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 769
PROMPT_TOKENS = 760
COMPLETION_TOKENS = 9

# %% [markdown]
# ---
