# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:17:55.164723+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "Instruction text reads: 'Pick the dice pair with the same icon facing up (1 of 1)'.")
    describe(1, "Six pairs of dice are displayed, each pair showing different icons on their top faces.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides the task instruction, and Frame 1 shows the dice pairs to solve the task.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective("Click on the pair of dice in Frame 1 where the top faces of both dice display the same icon.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0 is the instruction frame, so it is non-interactable
    # Frame 1 contains the dice pairs, which are interactable

    # Split Frame 1 into subframes for each pair of dice
    subframes = frames[1].split(rows=2, columns=3)

    # Set each subframe as SELECTABLE since we need to click on the correct pair
    for subframe in subframes:
        subframe.set_frame_as('SELECTABLE')

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Extract images from frames 1 to 6
    images = [frame.image for frame in frames[1:7]]

    # Mark the icons on the dice
    marked_images = mark(images, "icon")

    # Ask which pair of dice have the same icon facing up
    same_icon_pair = ask(marked_images, "Which pair of dice have the same icon facing up?", answer_type="int")

    # Select the frame with the matching pair
    select(frames[same_icon_pair[0] + 1])

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: Which pair of dice have the same icon facing up?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[0, 4])
'''
TIME = 2.351214969996363
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1579
PROMPT_TOKENS = 1570
COMPLETION_TOKENS = 9

# %% [markdown]
# ---
