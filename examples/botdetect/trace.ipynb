# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:14:39.611589+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "A blank rectangular input field at the bottom of the frame, likely for text entry.")
    describe(1, "A distorted text image displaying the word 'S6PKY' with a dark background.")
    describe(2, "An instruction text that reads 'Retype the characters from the picture:'.")
    describe(3, "A button labeled 'Validate' for submitting the input.")

    # Step 2: Identify the relationships between frames.
    relate(2, 1, "Frame 2 provides instructions to interpret the distorted text in Frame 1.")
    relate(0, 1, "Frame 0 is the input field where the text from Frame 1 should be entered.")
    relate(3, 0, "Frame 3 validates the text entered in Frame 0.")

    # Step 3: Identify the sequential events and the final visual criteria.
    objective("Click on the input field, type the characters from the distorted text image, and press the 'Validate' button to complete the task.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0: Input field
    input_field = frames[0].get_element(position='down', details='rectangular input field with border')
    input_field.set_element_as(interactable='INPUTTABLE')
    
    # Frame 3: Validate button
    validate_button = frames[3].get_element(position='right', details='button labeled Validate')
    validate_button.set_element_as(interactable='NEXT')

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames: list) -> None:
    # Extract the CAPTCHA text from the image in Frame 1
    captcha_image = frames[1].image
    captcha_text = "S6PKY"  # Manually identified from the image

    # Get the input field element in Frame 0
    input_field = frames[0].get_interactable(0)

    # Enter the CAPTCHA text into the input field
    enter(input_field, captcha_text)

    # Click the "Validate" button in Frame 3
    validate_button = frames[3].get_interactable(0)
    click(validate_button)

# %% [markdown]
# ---
