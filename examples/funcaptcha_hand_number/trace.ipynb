# %% [markdown]
# # Execution Trace
# - **Start Timestamp (UTC)**: 2025-01-17T06:19:07.193304+00:00
# - **OS**: Linux 5.15.0-125-generic #135~20.04.1-Ubuntu SMP Mon Oct 7 13:56:22 UTC 2024
# - **Machine**: x86_64
# - **Python Info**: 3.12.4-final0
# - **Python Environment Hash**: 254ed744c6afa6cb7a82cb312f75f9fcd1c4da2c13d780212e30fa7339309c54
# - **CAPTCHA**:
#
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# ## Objective Identification

# %%
def stage1(frames):
    # Step 1: Provide one-sentence visual description of each frame.
    describe(0, "A text prompt instructs the user to pick the image where the total fingers add up to 4, with a note indicating '1 of 1'.")
    describe(1, "A grid of six images, each showing hands with varying numbers of fingers extended against colorful abstract backgrounds.")

    # Step 2: Identify the relationships between frames.
    relate(0, 1, "Frame 0 provides the task instructions, and Frame 1 contains the options to solve the task.")

    # Step 3: Identify the sequential events and final visual criteria.
    objective("Click on the image in Frame 1 where the total number of fingers shown adds up to 4, as instructed in Frame 0.")

# %% [markdown]
# ## Structure Abstraction

# %%
def stage2(frames):
    # Frame 0 is the instruction frame and is not interactable
    frame_0 = frames[0]
    
    # Frame 1 contains the images and should be split into selectable subframes
    frame_1 = frames[1]
    
    # Split Frame 1 into a grid of selectable subframes
    subframes = frame_1.split(rows=2, columns=3)
    
    # Mark each subframe as SELECTABLE
    for subframe in subframes:
        subframe.set_frame_as(interactable="SELECTABLE")

# %% [markdown]
# ## Solution Composition

# %%
def stage3(frames):
    # Mark the images to identify fingers
    marked_images = mark([frame.image for frame in frames[1:]], "fingers")
    
    # Ask how many fingers are in each marked image
    finger_counts = ask(marked_images, "What is the total number of fingers shown?", answer_type="int")
    
    # Find the image with the closest number of fingers to 4
    closest_index = min(range(len(finger_counts)), key=lambda i: abs(finger_counts[i] - 4))
    
    # Select the image with the closest count
    select(frames[closest_index + 1])

# %%
PROMPT = '''
## Objective
Given the list of images, answer the question: What is the total number of fingers shown?
Output a list of numbers for each image.
You should follow the format `answer(numbers=[1, 2, ...])` to answer the question.

'''

# %%
IMAGES = 6
# Out:
#     <div style="
#         display: grid;
#         grid-template-columns: repeat(5, auto);
#         column-gap: 10px;
#         row-gap: 10px;">
#         <div><img src="data:image/png;base64,..."/><p>Image 0</p></div><div><img src="data:image/png;base64,..."/><p>Image 1</p></div><div><img src="data:image/png;base64,..."/><p>Image 2</p></div><div><img src="data:image/png;base64,..."/><p>Image 3</p></div><div><img src="data:image/png;base64,..."/><p>Image 4</p></div><div><img src="data:image/png;base64,..."/><p>Image 5</p></div>
#     </div>

# %%
RESPONSE = '''
answer(numbers=[6, 8, 4, 3, 5, 2])
'''
TIME = 3.6586524480953813
FINGERPRINT = fp_60a3f2dc65
TOTAL_TOKENS = 1589
PROMPT_TOKENS = 1568
COMPLETION_TOKENS = 21

# %% [markdown]
# ---
